# %%
# !pip install pandas

# %% [markdown]
# We'll simulate a dataset for a retail e-commerce business with columns such as:
# - OrderID, CustomerID, OrderDate, ShipDate
# - Product, Category, Quantity, Price, Discount, Revenue, Country, PaymentMethod

# %%
import pandas as pd

# %%
df=pd.read_csv('sales.csv')

# %%
df.head(10)
# Out:
#    Order id  Custumer id   Order date  Ship date  Product  Category  \
# 0      72.0          22.0         1.0       31.0       TV         4
# 1      23.0          44.0        31.0        5.0   FRIDGE         5
# 2      69.0           3.0        19.0       26.0   MOBILE         1
# 3      83.0          21.0        18.0       26.0      NaN         4
# 4      44.0          57.0        24.0       24.0       TV         5
# 5       NaN           6.0        24.0        NaN   FRIDGE         3
# 6      93.0          17.0         9.0        8.0   MOBILE         5
# 7      85.0          61.0        31.0       13.0  GROCERY         2
# 8      67.0          54.0         NaN       11.0       TV         2
# 9      30.0          63.0         6.0       16.0   FRIDGE         1
#
#    Quantity     Price  Discount  Revenue Country Payment Method
# 0        1.0  14535.0         8      754   India            cod
# 1        3.0  27610.0        13      552   India         online
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order id        44 non-null     float64
#  1   Custumer id     47 non-null     float64
#  2   Order date      46 non-null     float64
#  3   Ship date       46 non-null     float64
#  4   Product         47 non-null     object
#  5   Category        49 non-null     int64
#  6   Quantity        47 non-null     float64
#  7   Price           48 non-null     float64
#  8   Discount        49 non-null     int64
#  9   Revenue         49 non-null     int64
#  10  Country         48 non-null     object
#  11  Payment Method  48 non-null     object
# dtypes: float64(6), int64(3), object(3)
# memory usage: 4.7+ KB

# %%
df.describe()
# Out:
#         Order id  Custumer id   Order date  Ship date   Category  Quantity   \
# count  44.000000     47.000000   46.000000  46.000000  49.000000  47.000000
# mean   55.250000     49.085106   16.804348  17.065217   2.979592   1.978723
# std    28.192136     26.074167    8.838350   8.494187   1.391788   0.846716
# min     4.000000      3.000000    1.000000   1.000000   1.000000   1.000000
# 25%    29.000000     26.000000   11.000000  10.250000   2.000000   1.000000
# 50%    53.000000     50.000000   18.000000  19.500000   3.000000   2.000000
# 75%    82.250000     70.500000   23.000000  23.750000   4.000000   3.000000
# max    98.000000     95.000000   31.000000  31.000000   5.000000   3.000000
#
#               Price   Discount     Revenue
# count     48.000000  49.000000   49.000000
# mean   30989.625000  10.081633  519.346939
# std    10823.557559   3.154605  228.519470
# min    12090.000000   5.000000  118.000000
# 25%    22060.500000   8.000000  333.000000
# ...

# %%
df.head()
# Out:
#                        Order id  Custumer id   Order date  Ship date Product  \
# 0 1970-01-01 00:00:00.000000072          22.0         1.0       31.0      TV
# 1 1970-01-01 00:00:00.000000023          44.0        31.0        5.0  FRIDGE
# 2 1970-01-01 00:00:00.000000069           3.0        19.0       26.0  MOBILE
# 3 1970-01-01 00:00:00.000000083          21.0        18.0       26.0     NaN
# 4 1970-01-01 00:00:00.000000044          57.0        24.0       24.0      TV
#
#    Category  Quantity     Price  Discount  Revenue Country Payment Method
# 0         4        1.0  14535.0         8      754   India            cod
# 1         5        3.0  27610.0        13      552   India         online
# 2         1        2.0  26414.0         6      569   India            cod
# 3         4        2.0  37152.0         8      646   India         online
# 4         5        1.0  40342.0        11      262   India            cod

# %%
df[["Product",'Custumer id ']].nunique()
# Out:
# Product          4
# Custumer id     38
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Order id          5
# Custumer id       2
# Order date        3
# Ship date         3
# Product           2
# Category          0
# Quantity          2
# Price             1
# Discount          0
# Revenue           0
# Country           1
# Payment Method    1
# dtype: int64

# %%
# Out:
#                         Order id  Custumer id   Order date  Ship date Product  \
# 0  1970-01-01 00:00:00.000000072          22.0         1.0       31.0      TV
# 4  1970-01-01 00:00:00.000000044          57.0        24.0       24.0      TV
# 8  1970-01-01 00:00:00.000000067          54.0         NaN       11.0      TV
# 12 1970-01-01 00:00:00.000000063           NaN         4.0        6.0      TV
# 16 1970-01-01 00:00:00.000000092          93.0        17.0        3.0      TV
#
#     Category  Quantity     Price  Discount  Revenue Country Payment Method
# 0          4        1.0  14535.0         8      754   India            cod
# 4          5        1.0  40342.0        11      262   India            cod
# 8          2        1.0  17847.0         5      291   India            cod
# 12         2        3.0  31001.0        11      522   India            cod
# 16         4        2.0  18266.0        15      436   India            cod

# %%
# Out:
# Total revenue generated by selling Tv is 5879

# %%
df['Ship date'].fillna(df['Ship date'].mean(),inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_232\2296302730.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Ship date'].fillna(df['Ship date'].mean(),inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order id        44 non-null     float64
#  1   Custumer id     47 non-null     float64
#  2   Order date      46 non-null     float64
#  3   Ship date       49 non-null     float64
#  4   Product         47 non-null     object
#  5   Category        49 non-null     int64
#  6   Quantity        47 non-null     float64
#  7   Price           48 non-null     float64
#  8   Discount        49 non-null     int64
#  9   Revenue         49 non-null     int64
#  10  Country         48 non-null     object
#  11  Payment Method  48 non-null     object
# dtypes: float64(6), int64(3), object(3)
# memory usage: 4.7+ KB

# %%
df['Order id'] = pd.to_datetime(df['Order id'])

# %%
df['Order id'].drop_duplicates(inplace=True)

# %%
df[df['Revenue']>500]
# Out:
#                         Order id  Custumer id   Order date  Ship date  \
# 0  1970-01-01 00:00:00.000000072          22.0         1.0  31.000000
# 1  1970-01-01 00:00:00.000000023          44.0        31.0   5.000000
# 2  1970-01-01 00:00:00.000000069           3.0        19.0  26.000000
# 3  1970-01-01 00:00:00.000000083          21.0        18.0  26.000000
# 5                            NaT           6.0        24.0  17.065217
# 6  1970-01-01 00:00:00.000000093          17.0         9.0   8.000000
# 11 1970-01-01 00:00:00.000000046          95.0        17.0  27.000000
# 12 1970-01-01 00:00:00.000000063           NaN         4.0   6.000000
# 13 1970-01-01 00:00:00.000000045          38.0        27.0   9.000000
# 14 1970-01-01 00:00:00.000000074          48.0         5.0  12.000000
# 15                           NaT          76.0        20.0  20.000000
# 17 1970-01-01 00:00:00.000000091          33.0         1.0  29.000000
# ...

# %%
df[df['Ship date']>df['Order date']]
# Out:
#                         Order id  Custumer id   Order date  Ship date  \
# 0  1970-01-01 00:00:00.000000072          22.0         1.0  31.000000
# 2  1970-01-01 00:00:00.000000069           3.0        19.0  26.000000
# 3  1970-01-01 00:00:00.000000083          21.0        18.0  26.000000
# 9  1970-01-01 00:00:00.000000030          63.0         6.0  16.000000
# 10 1970-01-01 00:00:00.000000086          33.0        18.0  22.000000
# 11 1970-01-01 00:00:00.000000046          95.0        17.0  27.000000
# 12 1970-01-01 00:00:00.000000063           NaN         4.0   6.000000
# 14 1970-01-01 00:00:00.000000074          48.0         5.0  12.000000
# 17 1970-01-01 00:00:00.000000091          33.0         1.0  29.000000
# 19 1970-01-01 00:00:00.000000026          18.0        19.0  21.000000
# 21 1970-01-01 00:00:00.000000026          27.0        15.0  31.000000
# 23 1970-01-01 00:00:00.000000048          18.0        11.0  12.000000
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22 entries, 0 to 47
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order id        21 non-null     datetime64[ns]
#  1   Custumer id     21 non-null     float64
#  2   Order date      22 non-null     float64
#  3   Ship date       22 non-null     float64
#  4   Product         20 non-null     object
#  5   Category        22 non-null     int64
#  6   Quantity        22 non-null     float64
#  7   Price           21 non-null     float64
#  8   Discount        22 non-null     int64
#  9   Revenue         22 non-null     int64
#  10  Country         21 non-null     object
#  11  Payment Method  21 non-null     object
# dtypes: datetime64[ns](1), float64(5), int64(3), object(3)
# memory usage: 2.2+ KB

# %%
df[(df['Payment Method']=="credit card")& (df['Country']=="us")]
# Out:
#                         Order id  Custumer id   Order date  Ship date  \
# 7  1970-01-01 00:00:00.000000085          61.0        31.0       13.0
# 36 1970-01-01 00:00:00.000000078          76.0         NaN        3.0
# 47 1970-01-01 00:00:00.000000007          43.0        16.0       23.0
#
#     Product  Category  Quantity     Price  Discount  Revenue Country  \
# 7   GROCERY         2        3.0  45815.0        15      150      us
# 36       TV         2        2.0  31145.0         9      775      us
# 47  GROCERY         2        1.0  33484.0         7      866      us
#
#    Payment Method
# 7     credit card
# 36    credit card
# 47    credit card

# %%
df.columns
# Out:
# Index(['Order id', 'Custumer id ', 'Order date', 'Ship date', 'Product',
#        'Category', 'Quantity ', 'Price', 'Discount', 'Revenue', 'Country',
#        'Payment Method'],
#       dtype='object')

# %%
df[(df['Custumer id ']>20)& (df['Custumer id ']<30)]
# Out:
#                         Order id  Custumer id   Order date  Ship date  \
# 0  1970-01-01 00:00:00.000000072          22.0         1.0  31.000000
# 3  1970-01-01 00:00:00.000000083          21.0        18.0  26.000000
# 21 1970-01-01 00:00:00.000000026          27.0        15.0  31.000000
# 25 1970-01-01 00:00:00.000000078          21.0         NaN  17.065217
# 43 1970-01-01 00:00:00.000000024          25.0        23.0   1.000000
# 46 1970-01-01 00:00:00.000000082          28.0         5.0  17.065217
#
#     Product  Category  Quantity     Price  Discount  Revenue Country  \
# 0        TV         4        1.0  14535.0         8      754   India
# 3       NaN         4        2.0  37152.0         8      646   India
# 21   FRIDGE         3        3.0  49181.0        12      494   India
# 25   FRIDGE         3        1.0  47705.0         8      330   India
# 43  GROCERY         1        1.0  31910.0         8      535   India
# ...

# %%
dftv = df[df["Product"] == "TV"]
dftv.head()
# Out:
#                         Order id  Custumer id   Order date  Ship date Product  \
# 0  1970-01-01 00:00:00.000000072          22.0         1.0       31.0      TV
# 4  1970-01-01 00:00:00.000000044          57.0        24.0       24.0      TV
# 8  1970-01-01 00:00:00.000000067          54.0         NaN       11.0      TV
# 12 1970-01-01 00:00:00.000000063           NaN         4.0        6.0      TV
# 16 1970-01-01 00:00:00.000000092          93.0        17.0        3.0      TV
#
#     Category  Quantity     Price  Discount  Revenue Country Payment Method
# 0          4        1.0  14535.0         8      754   India            cod
# 4          5        1.0  40342.0        11      262   India            cod
# 8          2        1.0  17847.0         5      291   India            cod
# 12         2        3.0  31001.0        11      522   India            cod
# 16         4        2.0  18266.0        15      436   India            cod

# %%
Tortal_evenue_for_Tv = dftv["Revenue"].sum()
print(f"Total revenue generated by selling Tv is {Tortal_evenue_for_Tv}")
total_tv_sold=dftv["Quantity"].sum()
# Out:
# Total revenue generated by selling Tv is 5879
